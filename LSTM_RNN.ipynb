# %% [markdown]
# # Deep Learning HW3
# @author BAIM Mohamed Jalal, 313551810

# %%
import io
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# # SimpleRNN

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Load the dataset
path_to_file = tf.keras.utils.get_file(
    'shakespeare.txt',
    'https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt'
)

# Read the text
with open(path_to_file, 'r') as f:
    text = f.read()

# Step 2: Preprocess the data
vocab = sorted(set(text))  # unique characters
char2idx = {char: idx for idx, char in enumerate(vocab)}
idx2char = np.array(vocab)
text_as_int = np.array([char2idx[c] for c in text])

seq_length = 50
dataset = tf.data.Dataset.from_tensor_slices(text_as_int)
sequences = dataset.batch(seq_length + 1, drop_remainder=True)

def split_input_target(chunk):
    input_text = chunk[:-1]
    target_text = chunk[1:]
    return input_text, target_text

dataset = sequences.map(split_input_target)

BATCH_SIZE = 64
BUFFER_SIZE = 10000
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

val_split = 0.2
total_batches = len(dataset)
val_batches = int(total_batches * val_split)

val_dataset = dataset.take(val_batches)
train_dataset = dataset.skip(val_batches)

# Step 3: Build the Simple RNN model_RNN
vocab_size = len(vocab)
embedding_dim = 256
rnn_units = 1024

model_RNN = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim),
    tf.keras.layers.SimpleRNN(rnn_units, return_sequences=True, recurrent_initializer='glorot_uniform'),
    tf.keras.layers.Dense(vocab_size)
])

# Define a loss function for BPC
def bpc_loss(labels, logits):
    loss = tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
    return tf.reduce_mean(loss) / tf.math.log(2.0)

# Compile the model_RNN
model_RNN.compile(optimizer='adam', loss=bpc_loss)

# Custom callback for breakpoints
class BreakpointCallback(tf.keras.callbacks.Callback):
    def __init__(self, breakpoints, text, num_generate=500):
        self.breakpoints = breakpoints
        self.text = text
        self.num_generate = num_generate

    def on_epoch_end(self, epoch, logs=None):
        if epoch in self.breakpoints:
            print(f"\n--- Breakpoint at Epoch {epoch + 1} ---")
            seed_text = self.text[:100]
            generated_text = generate_text(model_RNN, seed_text, self.num_generate)
            print(generated_text)

# Text generation function
def generate_text(model_RNN, start_string, num_generate=500):
    input_eval = [char2idx[c] for c in start_string]
    input_eval = tf.expand_dims(input_eval, 0)
    text_generated = []

    temperature = 1.0

    # Generate predictions character by character
    for _ in range(num_generate):
        predictions = model_RNN(input_eval)
        predictions = tf.squeeze(predictions, 0)
        predictions = predictions / temperature
        predicted_id = tf.random.categorical(predictions, num_samples=1)[-1, 0].numpy()

        # Add the predicted character to the input
        input_eval = tf.expand_dims([predicted_id], 0)
        text_generated.append(idx2char[predicted_id])

    return start_string + ''.join(text_generated)


# Train the model_RNN with callbacks for breakpoints
EPOCHS = 50
breakpoints = [10, 20, 30, 35, 40]

history = model_RNN.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    callbacks=[BreakpointCallback(breakpoints, text)]
)

# Step 5: Plot learning curves
train_bpc = history.history['loss']
val_bpc = history.history['val_loss']

plt.plot(range(EPOCHS), train_bpc, label='Training BPC')
plt.plot(range(EPOCHS), val_bpc, label='Validation BPC')
plt.xlabel('Epochs')
plt.ylabel('Bits-per-Character (BPC)')
plt.legend()
plt.title('Learning Curves')
plt.show()

# Step 6: Calculate and display error rates
train_error_rate = 1 - np.exp(-np.array(train_bpc))
val_error_rate = 1 - np.exp(-np.array(val_bpc))

print("Last train error rate:",train_error_rate[-1])
print("Last validation error rate:",val_error_rate[-1])

plt.plot(range(EPOCHS), train_error_rate, label='Training Error Rate')
plt.plot(range(EPOCHS), val_error_rate, label='Validation Error Rate')
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.legend()
plt.title('Training and Validation Error Rates')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# 1115394/1115394 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732895580.617616     187 service.cc:145] XLA service 0x7aac68003030 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732895580.617708     187 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#  11/273 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 5.7716
# I0000 00:00:1732895581.946184     187 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 4.1051 - val_loss: 2.9404
# Epoch 2/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.8010 - val_loss: 2.5436
# Epoch 3/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.4797 - val_loss: 2.3630
# Epoch 4/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.3131 - val_loss: 2.2381
# Epoch 5/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.2131 - val_loss: 2.1661
# Epoch 6/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.1429 - val_loss: 2.0988
# Epoch 7/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.1016 - val_loss: 2.0738
# Epoch 8/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.0535 - val_loss: 2.0280
# Epoch 9/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 2.0258 - val_loss: 2.0116
# Epoch 10/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.9942 - val_loss: 1.9830
# Epoch 11/50
# 272/273 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9742
# --- Breakpoint at Epoch 11 ---
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You fore ber te y wns scewonerich awake herwim.
# Fies, we t whe, bl me lyomirs ibe t s:
#
# HAn sary f navifr in.
# Wearous o h to hagh Y: featero becolesher t y my tee wif, mavet fuby l th t wreroubere bes, beerese il. m tha and wige atoorer ovelee parou list itheaicoqurd ou bllangobre, lle foftomeckeverd uereampisike RYooncousheraviomerer llasimestom ENG fesilllicr, t sh thouthend bl ne harod; icla' tthous are vend ad lie!
# AUCAG gnd te avesw hane, we.
# ANGou mizepyithanthard mos w wrk me
# HIO: gr! is bra
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - loss: 1.9742 - val_loss: 1.9645
# Epoch 12/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.9518 - val_loss: 1.9442
# Epoch 13/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.9303 - val_loss: 1.9148
# Epoch 14/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.9080 - val_loss: 1.9014
# Epoch 15/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.8922 - val_loss: 1.8956
# Epoch 16/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.8784 - val_loss: 1.8784
# Epoch 17/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.8595 - val_loss: 1.8711
# Epoch 18/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.8497 - val_loss: 1.8518
# Epoch 19/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.8321 - val_loss: 1.8391
# Epoch 20/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.8163 - val_loss: 1.8195
# Epoch 21/50
# 272/273 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8071
# --- Breakpoint at Epoch 21 ---
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# Yourtoono bescen
# S:
#
# K: ofreerilly ho athed ithelitomird e her Rearalis n trthis h bunke o the ses HAg igofr, y s ld,
# KIAUCHAs thalo s ABENIZAn'd w, helo dandirthf thaiot me, he.
# SThthe, a t the w ay busery'shir pieall!
# ppaby IOfrers lpelore my:
# WOfo cor ith l r aneermped t o. asitldeesore; ds IETI or t ital'e n, ffay mpilirbo' sto we:
# I pr ENCENCHa bbuthy h, talat d br bo Gongemugedo be, t tu?
# Sod.
# FO:
#
# Buputhion, as s or we d iey.
# NCKI thasoun I bof cerare sat ce bber ch's w,
# Bitharshinow Ed buso
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - loss: 1.8071 - val_loss: 1.8134
# Epoch 22/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.7948 - val_loss: 1.8115
# Epoch 23/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.7800 - val_loss: 1.7986
# Epoch 24/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.7631 - val_loss: 1.7814
# Epoch 25/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.7581 - val_loss: 1.7807
# Epoch 26/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.7452 - val_loss: 1.7620
# Epoch 27/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.7332 - val_loss: 1.7695
# Epoch 28/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.7254 - val_loss: 1.7406
# Epoch 29/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.7169 - val_loss: 1.7418
# Epoch 30/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.7108 - val_loss: 1.7364
# Epoch 31/50
# 270/273 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7026
# --- Breakpoint at Epoch 31 ---
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You deal, cakerdos dore me m thopy oceat
#
#
# A mofive aberagothinoverdeastha po ost by,
# Whaf f hoct,
# FOxpave hater,
#
# h twarerdert kshee:
#
# CINAs, f ay athe yome, t IES:
# k, hea?
# HI the at IS:
# Pe ourt, y arder!
# ORELORDR:
# Ong, w e.
# Frofresusongee Cayou loo paine fecaldar ESoofre at RY:
# k'shenomondoothimy, prondyous g?
# VORDWellaving t, sof l atho!
#
#
# Bund y goryeaispeare br:
# H:
# LAnd be he.
# Tronge by othind'stow's atheasosicomod ooup bs, ngulots ANourabek ker oougo nfan, ge PE s myayot t frgowntherund lof k
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - loss: 1.7025 - val_loss: 1.7209
# Epoch 32/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6898 - val_loss: 1.7204
# Epoch 33/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6869 - val_loss: 1.7289
# Epoch 34/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6825 - val_loss: 1.7091
# Epoch 35/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6770 - val_loss: 1.7234
# Epoch 36/50
# 272/273 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6718
# --- Breakpoint at Epoch 36 ---
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You pe d ird lan. afou.
# Norone s s ist f y ise w s wind as'se pithobe he oss bin oo!
# We s itinonts sck hilphe ffre th,
# KE atey s th al ave, k w, d minerin
# TI:
# Bokeros lin ou hen itherbr octh kir.
# CI this O:
# S:
# An is?
# I; ind bor bir ny 's bu
# 'd herelow oros aree,
# NIUClarincosofo'sobouioutormathire ur y
# Heyjure iryeiry, t-fo aves oubey sh Arte d yougerker s umesh CANAGBABAgonche anthinf an t lars tcaut m stet fyeirse va moumat pe yoby younth,
# MI's lin.
#
# Ar, Ke hyitowierifod lleryourou arok aructhothy
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - loss: 1.6718 - val_loss: 1.7094
# Epoch 37/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6654 - val_loss: 1.6910
# Epoch 38/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6573 - val_loss: 1.6922
# Epoch 39/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6550 - val_loss: 1.6874
# Epoch 40/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6486 - val_loss: 1.6973
# Epoch 41/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6474
# --- Breakpoint at Epoch 41 ---
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You I n s herer suthes palldathet y
# IVI ta yollleat thesheer ig nofe: broteat thele y MIZANSELividedweres.
# OR:
# And coket, t.
# ADAw, coupo ste d s t her
# FRULULo whet Rof
# KESThenigoder, y mingofert t,
# IXESor t.
# Wheay wifals,
#
# TARMI s n hertee yor sid Tr t,
# KES:
# Whe isly WAn, atcoseteratierdser or, HARA:
# She tonsh wansporarin uer ke.
# LOWhekyo four, s an:
# An af My tinshade,
# SENGLOUKI thern n andy thege oneshe n pond t.
# N:
# Be orso tr TI theng-fondd,
# Qunaton'saroun an
# WI cheing Awisthe h, I ces MIf t Bort
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - loss: 1.6474 - val_loss: 1.6904
# Epoch 42/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6457 - val_loss: 1.6870
# Epoch 43/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6482 - val_loss: 1.6961
# Epoch 44/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6457 - val_loss: 1.6980
# Epoch 45/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6452 - val_loss: 1.6896
# Epoch 46/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6375 - val_loss: 1.6761
# Epoch 47/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6378 - val_loss: 1.6814
# Epoch 48/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6371 - val_loss: 1.6976
# Epoch 49/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6392 - val_loss: 1.6827
# Epoch 50/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - loss: 1.6392 - val_loss: 1.6857
# Last train error rate: 0.8043592500867387
# Last validation error rate: 0.814690580192189

# %%
# Training on different hidden units and parameters

def train_rnn(hidden_units, seq_length, epochs=10):
    # Create new dataset with specified sequence length
    sequences = tf.data.Dataset.from_tensor_slices(text_as_int).batch(seq_length + 1, drop_remainder=True)
    sequences = sequences.map(split_input_target)
    dataset = sequences.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
    
    val_batches = int(len(dataset) * val_split)
    val_dataset = dataset.take(val_batches)
    train_dataset = dataset.skip(val_batches)

    # Define the model
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim),
        tf.keras.layers.SimpleRNN(
            units=hidden_units, 
            return_sequences=True, 
            recurrent_initializer='glorot_uniform'
        ),
        tf.keras.layers.Dense(vocab_size)
    ])

    # Compile the model
    model.compile(optimizer='adam', loss=bpc_loss)

    # Train the model
    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=epochs,
        verbose=0  # Suppress detailed logs for faster experimentation
    )

    return history.history['loss'], history.history['val_loss']

# Parameter values to test
hidden_sizes = [256, 512, 1024]
sequence_lengths = [50, 100, 200]
EPOCHS = 10  # Use fewer epochs for faster comparison

# Results dictionary
results = {}

# Run experiments for each combination of parameters
for hidden_units in hidden_sizes:
    for seq_length in sequence_lengths:
        print(f"Training with hidden_units={hidden_units}, seq_length={seq_length}")
        train_loss, val_loss = train_rnn(hidden_units, seq_length, EPOCHS)
        results[(hidden_units, seq_length)] = (train_loss, val_loss)

# Plot training loss for different configurations
plt.figure(figsize=(12, 8))
for (hidden_units, seq_length), (train_loss, val_loss) in results.items():
    plt.plot(train_loss, label=f"Units={hidden_units}, SeqLen={seq_length}")

plt.xlabel('Epochs')
plt.ylabel('Training BPC Loss')
plt.title('Training Loss vs. Hidden Units and Sequence Length')
plt.legend()
plt.show()
# Out:
# Training with hidden_units=256, seq_length=50
# Training with hidden_units=256, seq_length=100
# Training with hidden_units=256, seq_length=200
# Training with hidden_units=512, seq_length=50
# Training with hidden_units=512, seq_length=100
# Training with hidden_units=512, seq_length=200
# Training with hidden_units=1024, seq_length=50
# Training with hidden_units=1024, seq_length=100
# Training with hidden_units=1024, seq_length=200

# %% [markdown]
# ## LSTM

# %%
# Step 3: Build the LSTM model_LSTM
vocab_size = len(vocab)
embedding_dim = 256
rnn_units = 1024

model_LSTM = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim),
    tf.keras.layers.LSTM(rnn_units, return_sequences=True, recurrent_initializer='glorot_uniform'),
    tf.keras.layers.Dense(vocab_size)
])

# Compile the model_LSTM
model_LSTM.compile(optimizer='adam', loss=bpc_loss)


# Train the model_LSTM with callbacks for breakpoints
EPOCHS = 50
breakpoints = [10, 20, 30, 35, 40]

history_LSTM = model_LSTM.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    callbacks=[BreakpointCallback(breakpoints, text)]
)

# Step 5: Plot learning curves
train_bpc = history_LSTM.history['loss']
val_bpc = history_LSTM.history['val_loss']

plt.plot(range(EPOCHS), train_bpc, label='Training BPC')
plt.plot(range(EPOCHS), val_bpc, label='Validation BPC')
plt.xlabel('Epochs')
plt.ylabel('Bits-per-Character (BPC)')
plt.legend()
plt.title('Learning Curves')
plt.show()

# Step 6: Calculate and display error rates
train_error_rate = 1 - np.exp(-np.array(train_bpc))
val_error_rate = 1 - np.exp(-np.array(val_bpc))

plt.plot(range(EPOCHS), train_error_rate, label='Training Error Rate')
plt.plot(range(EPOCHS), val_error_rate, label='Validation Error Rate')
plt.xlabel('Epochs')
plt.ylabel('Error Rate')
plt.legend()
plt.title('Training and Validation Error Rates')
plt.show()
# Out:
# Epoch 1/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - loss: 4.2025 - val_loss: 2.9056
# Epoch 2/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.7512 - val_loss: 2.4504
# Epoch 3/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.3751 - val_loss: 2.2209
# Epoch 4/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.1825 - val_loss: 2.0965
# Epoch 5/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.0766 - val_loss: 2.0170
# Epoch 6/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.9949 - val_loss: 1.9582
# Epoch 7/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.9402 - val_loss: 1.8940
# Epoch 8/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.8795 - val_loss: 1.8463
# Epoch 9/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.8305 - val_loss: 1.8093
# Epoch 10/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.7868 - val_loss: 1.7623
# Epoch 11/50
# 271/273 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.7390
# --- Breakpoint at Epoch 11 ---
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You bechu s
# TOR:
# An thoucowhiceit 'ss!
# be pame!
# JUKagithot o-ve gnchan k.
# NG t s as o a the bouas t dl pre,
#
# LOFind
#
#
# A f S era ifrion CELOLAn:
#
#
# PANELARYo meshowearholthe su theme.
# wamom the sed-' ISit we f t st whoot we cheswotonenseng matewlance ma tres been,
# We thatupr,
#
# LLak at oll-bol, thizze.
# thethe n
#
# RADUS:
#
# ANavilind bewe;
# TIORI mof o st is'd ayothen thilas ll, ast sthilato' makecearyory byoun.
# CLORA:
# Whancr mame wnanindoly:
# Tha d hth IO: We wnceans d ilorous.
# MENThanco w w WI he,
# PENo he
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 15s 51ms/step - loss: 1.7390 - val_loss: 1.7228
# Epoch 12/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.6941 - val_loss: 1.6798
# Epoch 13/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.6423 - val_loss: 1.6253
# Epoch 14/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.5886 - val_loss: 1.5791
# Epoch 15/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.5338 - val_loss: 1.5261
# Epoch 16/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.4783 - val_loss: 1.4759
# Epoch 17/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.4159 - val_loss: 1.4192
# Epoch 18/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.3475 - val_loss: 1.3635
# Epoch 19/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.2900 - val_loss: 1.3032
# Epoch 20/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.2292 - val_loss: 1.2474
# Epoch 21/50
# 272/273 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.1677
# --- Breakpoint at Epoch 21 ---
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# Yourr sthurt by, brloreewanfithind s ghoubybrd we at wn doug h bea alloma'sirereatoun LARelock
# APUpl, t go hines,
#
# Bodettowendime:
# IXESis tethinonorosca am! byowinomatomat beaf oree Vithe Ayovispe.
# HANorty f ts anovid sind g r ncomotegut Bedd h:
# TR:
# I g hathadof A:
#
# LUSie d I g;
# The, ou I'?
# 'se tyor'!
# Gowhit har ry f sak:
# Awallo tthall cou me il, the my by ar.
# dingbeatw.
# MELoultsicernol.
# wameame,
# th,
# Ism bar sshin, O:
# win
#
# t-prs me
# HEORTHer,
# The
# Weeallve opourmaild bert thinth ld ve mauran aveng Ri
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 15s 51ms/step - loss: 1.1676 - val_loss: 1.2003
# Epoch 22/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.1117 - val_loss: 1.1311
# Epoch 23/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.0600 - val_loss: 1.0876
# Epoch 24/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.0007 - val_loss: 1.0416
# Epoch 25/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.9562 - val_loss: 0.9948
# Epoch 26/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.9149 - val_loss: 0.9534
# Epoch 27/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.8689 - val_loss: 0.9149
# Epoch 28/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.8334 - val_loss: 0.8720
# Epoch 29/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.7951 - val_loss: 0.8397
# Epoch 30/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.7611 - val_loss: 0.8175
# Epoch 31/50
# 272/273 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.7390
# --- Breakpoint at Epoch 31 ---
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You k hine ge mas LULAno Corgr KIORMyongomams;
# Wh yorer tedll,
# win h anhed.
# But.
# KIXExtelley ns Tyo mmat be ABis ncemey:
# VI w t oft medize f gaterm.
# TERDY:
# YOnchiraveat t youesteses ememar s?
#
#
# TH
# MELO be meverorotile
# Whe
# w sit TRowllle de,
# withe ad:
# VOS:
# SThas p minththe;
# Ma deeveesom,
# HAN oustily Sor.
# Hisan bratice mpather, qulste appe ppecayintr ha to t d k;
# Pam, pin thars Voasort kis,
# Whesher!
# TIARitomor queair Y:
# I bee ture ' rm, ingnce atite and y s owiveditinge l alasthose.
# Ang afo, s,
#
#
# ARA
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 15s 51ms/step - loss: 0.7389 - val_loss: 0.7915
# Epoch 32/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.7151 - val_loss: 0.7595
# Epoch 33/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.6871 - val_loss: 0.7398
# Epoch 34/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.6690 - val_loss: 0.7159
# Epoch 35/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.6509 - val_loss: 0.6932
# Epoch 36/50
# 272/273 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6361
# --- Breakpoint at Epoch 36 ---
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You Wesomesige we! t owalatiscth, whand g d dinostrowhord hearcin yo wiveve bletear
# RERis qur, weff
# Y:
# HORDUCHen'sprhaitchateat, leh.
# OR:
# Th hetisp
# TUS:
# Bul touro hichilar:
# PULORD Ifos tha s, try; ithive go; y alowince-dsselditixtisto ourve be memy Nerok d ye:
# TINAnoun fthe othy' HARTh aut st:
# Gove thant a h imo-d deastistor
#
# An'stilf my'd he y sourd d s, tes l.
# VI g h w whe MIn
# O:
#
# Aflathand canort mmbet.
# APETHe, h be;
# KI s:
#
# tud amyouthessot nys l, te.
# Is doot, hexar w.
# PELone:
# Bu.
# Ay mal f GRD w
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 15s 51ms/step - loss: 0.6360 - val_loss: 0.6790
# Epoch 37/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.6168 - val_loss: 0.6678
# Epoch 38/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.6046 - val_loss: 0.6582
# Epoch 39/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5976 - val_loss: 0.6408
# Epoch 40/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5844 - val_loss: 0.6373
# Epoch 41/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5745
# --- Breakpoint at Epoch 41 ---
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You'Mur nde ndouth coverll tueagou wandnomat s s K:
# THI cll artres f
# VONainth gan be me oze w chepesthou in mpailo inowithive a wrff y ode:
#
# Wice hapis f s;
# Thaind
#
# HOMye averg h'tor sawayoo wh ce TEdngncts id thest bongrte nce lis wind ou t riearwe.
# Anotis GBen An an.
# ARUCAD uriase ls no Gorlthout rthome dofo robe or wngaf than Ayorur,
# D tomanu lf ordyo ak:
# BARUCEToncan, akindilthameh.
# ppad d wos inso aleailontert u, scessict brunornovane tetin mece mayot.
# Tou momas, s ito n Ingoocowe.
# JOMoveanght
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 15s 51ms/step - loss: 0.5745 - val_loss: 0.6291
# Epoch 42/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5716 - val_loss: 0.6188
# Epoch 43/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5617 - val_loss: 0.6024
# Epoch 44/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5502 - val_loss: 0.6015
# Epoch 45/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5481 - val_loss: 0.5931
# Epoch 46/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5392 - val_loss: 0.5949
# Epoch 47/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5424 - val_loss: 0.5866
# Epoch 48/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5354 - val_loss: 0.5806
# Epoch 49/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5276 - val_loss: 0.5807
# Epoch 50/50
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 0.5238 - val_loss: 0.5685

# %%
# Training on different hidden units and parameters

def train_rnn(hidden_units, seq_length, epochs=10):
    # Create new dataset with specified sequence length
    sequences = tf.data.Dataset.from_tensor_slices(text_as_int).batch(seq_length + 1, drop_remainder=True)
    sequences = sequences.map(split_input_target)
    dataset = sequences.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
    
    val_batches = int(len(dataset) * val_split)
    val_dataset = dataset.take(val_batches)
    train_dataset = dataset.skip(val_batches)

    # Define the model
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim),
        tf.keras.layers.LSTM(rnn_units, return_sequences=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size)
    ])

    # Compile the model
    model.compile(optimizer='adam', loss=bpc_loss)

    # Train the model
    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=epochs,
        verbose=1  # Suppress detailed logs for faster experimentation
    )

    return history.history['loss'], history.history['val_loss']

# Parameter values to test
hidden_sizes = [256, 512, 1024]
sequence_lengths = [50, 100, 200]
EPOCHS = 10  # Use fewer epochs for faster comparison

# Results dictionary
results = {}

# Run experiments for each combination of parameters
for hidden_units in hidden_sizes:
    for seq_length in sequence_lengths:
        print(f"Training with hidden_units={hidden_units}, seq_length={seq_length}")
        train_loss, val_loss = train_rnn(hidden_units, seq_length, EPOCHS)
        results[(hidden_units, seq_length)] = (train_loss, val_loss)

# Plot training loss for different configurations
plt.figure(figsize=(12, 8))
for (hidden_units, seq_length), (train_loss, val_loss) in results.items():
    plt.plot(train_loss, label=f"Units={hidden_units}, SeqLen={seq_length}")

plt.xlabel('Epochs')
plt.ylabel('Training BPC Loss')
plt.title('Training Loss vs. Hidden Units and Sequence Length')
plt.legend()
plt.show()
# Out:
# Training with hidden_units=256, seq_length=50
# Epoch 1/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - loss: 3.9371 - val_loss: 2.6798
# Epoch 2/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.5344 - val_loss: 2.2677
# Epoch 3/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.2096 - val_loss: 2.0960
# Epoch 4/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.0638 - val_loss: 1.9913
# Epoch 5/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.9638 - val_loss: 1.9204
# Epoch 6/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.9003 - val_loss: 1.8624
# Epoch 7/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.8339 - val_loss: 1.8000
# Epoch 8/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.7769 - val_loss: 1.7398
# Epoch 9/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.7187 - val_loss: 1.7030
# Epoch 10/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.6670 - val_loss: 1.6458
# Training with hidden_units=256, seq_length=100
# Epoch 1/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 4.2968 - val_loss: 2.9416
# Epoch 2/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.8056 - val_loss: 2.4731
# Epoch 3/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.4045 - val_loss: 2.2141
# Epoch 4/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.1741 - val_loss: 2.0706
# Epoch 5/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.0464 - val_loss: 1.9673
# Epoch 6/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.9621 - val_loss: 1.8905
# Epoch 7/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - loss: 1.8880 - val_loss: 1.8253
# Epoch 8/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.8335 - val_loss: 1.7694
# Epoch 9/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.7780 - val_loss: 1.7193
# Epoch 10/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.7216 - val_loss: 1.6670
# Training with hidden_units=256, seq_length=200
# Epoch 1/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 11s 117ms/step - loss: 4.6762 - val_loss: 3.2878
# Epoch 2/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 3.1580 - val_loss: 2.8387
# Epoch 3/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 2.7560 - val_loss: 2.5302
# Epoch 4/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 2.4918 - val_loss: 2.3334
# Epoch 5/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 2.3074 - val_loss: 2.1849
# Epoch 6/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 2.1779 - val_loss: 2.0807
# Epoch 7/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 117ms/step - loss: 2.0732 - val_loss: 1.9998
# Epoch 8/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 2.0035 - val_loss: 1.9445
# Epoch 9/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 116ms/step - loss: 1.9450 - val_loss: 1.8905
# Epoch 10/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 1.8789 - val_loss: 1.8286
# Training with hidden_units=512, seq_length=50
# Epoch 1/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - loss: 4.1640 - val_loss: 2.8311
# Epoch 2/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.6820 - val_loss: 2.3924
# Epoch 3/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.3251 - val_loss: 2.1843
# Epoch 4/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.1566 - val_loss: 2.0744
# Epoch 5/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.0539 - val_loss: 2.0081
# Epoch 6/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.9833 - val_loss: 1.9413
# Epoch 7/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.9225 - val_loss: 1.8905
# Epoch 8/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.8745 - val_loss: 1.8491
# Epoch 9/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.8260 - val_loss: 1.7988
# Epoch 10/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.7827 - val_loss: 1.7636
# Training with hidden_units=512, seq_length=100
# Epoch 1/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 4.2996 - val_loss: 2.9480
# Epoch 2/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.8103 - val_loss: 2.4807
# Epoch 3/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - loss: 2.4078 - val_loss: 2.2258
# Epoch 4/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.1935 - val_loss: 2.0840
# Epoch 5/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.0648 - val_loss: 1.9749
# Epoch 6/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - loss: 1.9771 - val_loss: 1.9114
# Epoch 7/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.9025 - val_loss: 1.8506
# Epoch 8/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.8506 - val_loss: 1.7846
# Epoch 9/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.7992 - val_loss: 1.7466
# Epoch 10/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.7440 - val_loss: 1.6941
# Training with hidden_units=512, seq_length=200
# Epoch 1/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 11s 116ms/step - loss: 4.7848 - val_loss: 3.3601
# Epoch 2/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 3.2130 - val_loss: 2.8982
# Epoch 3/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 2.8132 - val_loss: 2.6100
# Epoch 4/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 2.5565 - val_loss: 2.4190
# Epoch 5/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 2.3746 - val_loss: 2.2607
# Epoch 6/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 2.2414 - val_loss: 2.1472
# Epoch 7/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 2.1365 - val_loss: 2.0662
# Epoch 8/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 2.0577 - val_loss: 1.9973
# Epoch 9/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 1.9975 - val_loss: 1.9401
# Epoch 10/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 1.9418 - val_loss: 1.8961
# Training with hidden_units=1024, seq_length=50
# Epoch 1/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - loss: 4.1950 - val_loss: 2.8563
# Epoch 2/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.7041 - val_loss: 2.3972
# Epoch 3/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.3341 - val_loss: 2.1919
# Epoch 4/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.1541 - val_loss: 2.0707
# Epoch 5/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.0469 - val_loss: 1.9808
# Epoch 6/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.9732 - val_loss: 1.9334
# Epoch 7/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.9175 - val_loss: 1.8726
# Epoch 8/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.8582 - val_loss: 1.8363
# Epoch 9/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.8165 - val_loss: 1.7898
# Epoch 10/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.7627 - val_loss: 1.7449
# Training with hidden_units=1024, seq_length=100
# Epoch 1/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 4.2852 - val_loss: 2.9561
# Epoch 2/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.8252 - val_loss: 2.4925
# Epoch 3/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.4276 - val_loss: 2.2442
# Epoch 4/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.2177 - val_loss: 2.1014
# Epoch 5/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 2.0746 - val_loss: 1.9936
# Epoch 6/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.9894 - val_loss: 1.9212
# Epoch 7/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.9170 - val_loss: 1.8471
# Epoch 8/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.8512 - val_loss: 1.8006
# Epoch 9/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.8012 - val_loss: 1.7487
# Epoch 10/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.7581 - val_loss: 1.6986
# Training with hidden_units=1024, seq_length=200
# Epoch 1/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 11s 116ms/step - loss: 4.8099 - val_loss: 3.3583
# Epoch 2/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 3.2276 - val_loss: 2.9206
# Epoch 3/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 2.8299 - val_loss: 2.6267
# Epoch 4/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 2.5747 - val_loss: 2.4310
# Epoch 5/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 2.3977 - val_loss: 2.2776
# Epoch 6/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - loss: 2.2536 - val_loss: 2.1613
# Epoch 7/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 2.1488 - val_loss: 2.0875
# Epoch 8/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 2.0765 - val_loss: 2.0128
# Epoch 9/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 116ms/step - loss: 2.0065 - val_loss: 1.9583
# Epoch 10/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - loss: 1.9507 - val_loss: 1.8972

# %% [markdown]
# ## Priming the model

# %%
def priming_model(model, prime_text, char2idx, idx2char, num_generate=500, temperature=1.0):
    """
    Generates text by priming the model with a given input string.

    Args:
        model: Trained LSTM model.
        prime_text (str): Initial text to prime the model.
        char2idx (dict): Character-to-index mapping.
        idx2char (np.array): Index-to-character mapping.
        num_generate (int): Number of characters to generate.
        temperature (float): Sampling temperature for randomness.

    Returns:
        str: Generated text starting with the prime text.
    """
    # Convert the prime text to integer indices
    input_eval = [char2idx[c] for c in prime_text]
    input_eval = tf.expand_dims(input_eval, 0)

    text_generated = []

    # Generate text character by character
    for _ in range(num_generate):
        predictions = model(input_eval)
        predictions = tf.squeeze(predictions, 0)

        # Adjust the model's confidence with temperature
        predictions = predictions / temperature

        # Sample the next character
        predicted_id = tf.random.categorical(predictions, num_samples=1)[-1, 0].numpy()

        # Append the predicted character to the generated text
        text_generated.append(idx2char[predicted_id])

        # Update the input with the last predicted character
        input_eval = tf.expand_dims([predicted_id], 0)

    return prime_text + ''.join(text_generated)

# Use the function to generate text primed with "JULIET"
prime_text = "JULIET"

generated_text_RNN= priming_model(model_RNN, prime_text, char2idx, idx2char, num_generate=1000)
generated_text_LSTM = priming_model(model_LSTM, prime_text, char2idx, idx2char, num_generate=1000)

# Display the generated text
print("RNN:")
print("-"*50)
print(generated_text_RNN)
print('')
print("LSTM")
print("-"*50)
print(generated_text_LSTM)
# Out:
# RNN:
# --------------------------------------------------
# JULIET:
# TI th o omechit y, t m Lovelllee shee; callver bystia bhowanco IORAn, iren bus theay iers charearivalld blind whe-PUTur.
# Whank h s hor bl.
# Qullld thesesh h te I decacthilousto; rellea anou, it d swe chiteeethils Conkirsot,
# The myspro han g,
# A:
# MELA:
#
# Ifof hak tt be is, m
# Ad I'dle:
#
# Pr br ted, go wil yout t He,
# wantondsprase d, idse h;
# Yot atoo bhean bhawan tof ppl omavedsended the sest as sth, h ndurava w' o atond w alllle's noco ffral CAngh a hedive cavathing
# TRICLABomuchid sof nceendll, Wheloull!'see oupa CERVORTo th al yon--ORO:
# O:
# LAR:
# Michage fr ipalllir colll t uiandst ie weitwes this ormanet yonst turent le,
# Clotee.
# ETE e dee. te:
# whan-d?
# SESind orand bas torderitilllldind s hend il,
# M$Kan n han.
# ARD es d an, t mu war br, w the wealor ffou incery' fessske,
# Trthofe CLES oneamet
# QUKE par thepind.
#
#
# Fr
# wheis ' ESone beriveery iat orlofon st htithaverislyo'dind nd ith, be'tr gea thad,
# O:
# Gochatit ie, o eowir's marouthe athive l, ou matharie bin but fte ousthe me.
#
# ARARThicen'the,
#
# LSTM
# --------------------------------------------------
# JULIET:
# BO halelllirel t,
# TES:
# Whik'thandrey y t brl, EO:
# Ing,
# I y! gethathemexthe CUS: Codeshung reangbrtorea t w the at telloy nd.
# MNTh, HAndowhessts, t
# LI o t n,
# RYO:
# Qu't wousheninsug qut merict on, wary ntspowity ay weled,
#
# And alsatheyonofaris, ant
# Kinomo, beancar u hearereceallkine itimisisthavit!
# BI by u,
# Forcess amfrde y s,
# And, anariocenot m?
# Panoto a t'dou cakit thenon a?
# Fothe ithird ostethtod aieilers,
# Wiealloflleromay yoveveeey ha st grdes,
# D eave, He; iath bet ICincust:
#
# The,
# PED:
# wifrandath 'd byo scuto Mifatyend; tiges le in, ndise hioutreas ber
# Perorditey,
# Andes d go bedomind char wee but:
# As sede f se twa t a be It octhe!
# Pom byoreatherer cthag 'sse s,
# Wapasthe ceam me me, toowaghenathet mech,
# wenoo s BAULLO:
# I hetheco the dere hirono ak's wnonchese herp toremouthyby blllenthieikik woche ticllet at cout mer, omeng fousprea ow, per, hedistivende a whedet t heso at m, o ayobobys yola upo itr.
# Beabesseeakesereatiron n, cu hane yormssbemerid's
# S:
# WAndoe st ndinorverim o senit
